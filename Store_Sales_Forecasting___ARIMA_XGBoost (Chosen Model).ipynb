# %%
import numpy as np 
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Storing and reading the csv files

# %%
holiday_events = pd.read_csv('holidays_events.csv')
print(holiday_events.describe())
holiday_events.head()
# Out:
#               date     type    locale locale_name description transferred
# count          350      350       350         350         350         350
# unique         312        6         3          24         103           2
# top     2014-06-25  Holiday  National     Ecuador    Carnaval       False
# freq             4      221       174         174          10         338
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
oil = pd.read_csv('oil.csv', parse_dates = ['date'], index_col = 'date')
oil_test = oil.loc['2017-08-16' : '2017-08-31']
oil_test
# Out:
#             dcoilwtico
# date
# 2017-08-16       46.80
# 2017-08-17       47.07
# 2017-08-18       48.59
# 2017-08-21       47.39
# 2017-08-22       47.65
# 2017-08-23       48.45
# 2017-08-24       47.24
# 2017-08-25       47.65
# 2017-08-28       46.40
# 2017-08-29       46.46
# 2017-08-30       45.96
# 2017-08-31       47.26

# %%
stores = pd.read_csv('stores.csv')
stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
train_df = pd.read_csv('train.csv', parse_dates = ['date'], index_col = 'date')
train_df.head()
# Out:
#             id  store_nbr      family  sales  onpromotion
# date
# 2013-01-01   0          1  AUTOMOTIVE    0.0            0
# 2013-01-01   1          1   BABY CARE    0.0            0
# 2013-01-01   2          1      BEAUTY    0.0            0
# 2013-01-01   3          1   BEVERAGES    0.0            0
# 2013-01-01   4          1       BOOKS    0.0            0

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
transactions = pd.read_csv('transactions.csv')
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %% [markdown]
# #### Preprocessing the training data

# %%
train_df.dtypes
# Out:
# id               int64
# store_nbr        int64
# family          object
# sales          float64
# onpromotion      int64
# dtype: object

# %%
train_df.isna().sum()
# Out:
# id             0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64

# %%
train_df['family'].value_counts()
train_df['family'] = train_df['family'].astype('category')

# %%
train_df.dtypes
# Out:
# id                int64
# store_nbr         int64
# family         category
# sales           float64
# onpromotion       int64
# dtype: object

# %% [markdown]
# # Earthquake consequences on sales data

# %%
plt.figure(figsize=(16, 5))
plt.plot( train_df['sales'])
plt.title('Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# #### A closer look into the earthquake consequences reflected in sales.

# %% [markdown]
# Let's explore the large spike between 2016 and 2017

# %%
sample = train_df.loc['2016-02':'2016-05']
plt.figure(figsize=(20, 5))
plt.plot(sample['sales'])
plt.title('Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
city_sales = city_sales.reset_index()

# %%
city_sales.set_index('date', inplace=True)

# %%
city_sales
# Out:
#                      city          sales
# date
# 2013-01-01         Ambato       0.000000
# 2013-01-01       Babahoyo       0.000000
# 2013-01-01        Cayambe       0.000000
# 2013-01-01         Cuenca       0.000000
# 2013-01-01          Daule       0.000000
# ...                   ...            ...
# 2017-08-15        Quevedo   11649.571000
# 2017-08-15          Quito  341655.357968
# 2017-08-15       Riobamba    9342.732000
# 2017-08-15        Salinas    6522.788000
# 2017-08-15  Santo Domingo   30309.081000
#
# [37048 rows x 2 columns]

# %%
cities = ['Manta','Quito','Santo Domingo']
num_categories = len(cities)

# Define the number of rows and columns for the subplots
ncols = 3
nrows = (num_categories // ncols) + (num_categories % ncols > 0)  # Ensure enough rows

# Create subplots
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 4))
axes = axes.flatten()  # Flatten the 2D array of axes to easily iterate over

plt.rcParams.update({'font.size': 8})

# Plot each time series
for i, city in enumerate(cities):
    # Filter sales data for the current city
    sales_data = city_sales[city_sales['city'] == city]
    axes[i].plot(sales_data.index, sales_data['sales'])  # Plot date vs sales for the city
    axes[i].set_title(city)
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Sales')
    axes[i].grid(True)

# Remove any unused subplots
for j in range(num_categories, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# The increase in sales after 2016-04-15 for two weeks probably corresponds to the 7.8 magnitude earthquake at Ecuador

# %%
date = pd.to_datetime('2016-05-01')
day_of_week = date.dayofweek
print("Day of the Week:", day_of_week)
# Out:
# Day of the Week: 6

# %% [markdown]
# The *2016-05-01* is Sunday what can explain a low number of sales compared to the following day - Monday.
# Since 'Wages in the public sector are paid every two weeks on the 15 th and on the last day of the month', this can explain a high value of sales for Monday compared to the previous two weeks (after the earthquake).

# %% [markdown]
# # Adding features to the train_df and store_df

# %%
train_df
# Out:
#                  id  store_nbr                      family     sales  \
# date
# 2013-01-01        0          1                  AUTOMOTIVE     0.000
# 2013-01-01        1          1                   BABY CARE     0.000
# 2013-01-01        2          1                      BEAUTY     0.000
# 2013-01-01        3          1                   BEVERAGES     0.000
# 2013-01-01        4          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 2017-08-15  3000883          9                     POULTRY   438.133
# 2017-08-15  3000884          9              PREPARED FOODS   154.553
# 2017-08-15  3000885          9                     PRODUCE  2419.729
# 2017-08-15  3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2017-08-15  3000887          9                     SEAFOOD    16.000
#
#             onpromotion
# date
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# ...                 ...
# 2017-08-15            0
# 2017-08-15            1
# 2017-08-15          148
# 2017-08-15            8
# 2017-08-15            0
#
# [3000888 rows x 5 columns]

# %%
# adding sales and onpromotion values to the stores dataframe.
sales_and_onpromotion = train_df.groupby('store_nbr')[['sales', 'onpromotion']].sum()
stores = pd.merge(stores, sales_and_onpromotion, on = 'store_nbr', how = 'right')
stores.head(5)
# Out:
#    store_nbr           city                           state type  cluster  \
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
#
#           sales  onpromotion
# 0  1.414501e+07       138020
# 1  2.155739e+07       158149
# 2  5.048191e+07       177075
# 3  1.890970e+07       151932
# 4  1.559240e+07       149370

# %%
stores.dtypes
# Out:
# store_nbr        int64
# city            object
# state           object
# type            object
# cluster          int64
# sales          float64
# onpromotion      int64
# dtype: object

# %%
stores.head()
# Out:
#    store_nbr           city                           state type  cluster  \
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
#
#           sales  onpromotion
# 0  1.414501e+07       138020
# 1  2.155739e+07       158149
# 2  5.048191e+07       177075
# 3  1.890970e+07       151932
# 4  1.559240e+07       149370

# %%
total_transacts = transactions.groupby('store_nbr')['transactions'].sum()
stores = pd.merge(stores, total_transacts, on = 'store_nbr', how = 'right')
stores.head()
# Out:
#    store_nbr           city                           state type  cluster  \
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
#
#           sales  onpromotion  transactions
# 0  1.414501e+07       138020       2553963
# 1  2.155739e+07       158149       3219901
# 2  5.048191e+07       177075       5366350
# 3  1.890970e+07       151932       2519007
# 4  1.559240e+07       149370       2347877

# %% [markdown]
# **Let's now incorporate data from the *holiday_events* into the train_df.**

# %%
holiday_events.head(3)
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
#
#    transferred
# 0        False
# 1        False
# 2        False

# %%
train_df['holiday'] = 0

# %%
train_df
# Out:
#                  id  store_nbr                      family     sales  \
# date
# 2013-01-01        0          1                  AUTOMOTIVE     0.000
# 2013-01-01        1          1                   BABY CARE     0.000
# 2013-01-01        2          1                      BEAUTY     0.000
# 2013-01-01        3          1                   BEVERAGES     0.000
# 2013-01-01        4          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 2017-08-15  3000883          9                     POULTRY   438.133
# 2017-08-15  3000884          9              PREPARED FOODS   154.553
# 2017-08-15  3000885          9                     PRODUCE  2419.729
# 2017-08-15  3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2017-08-15  3000887          9                     SEAFOOD    16.000
#
#             onpromotion  holiday
# date
# 2013-01-01            0        0
# 2013-01-01            0        0
# 2013-01-01            0        0
# 2013-01-01            0        0
# 2013-01-01            0        0
# ...                 ...      ...
# 2017-08-15            0        0
# 2017-08-15            1        0
# 2017-08-15          148        0
# 2017-08-15            8        0
# 2017-08-15            0        0
#
# [3000888 rows x 6 columns]

# %%
# National holidays

holiday_events = holiday_events[holiday_events['transferred'] == False]
#now we have only non-transferred events.

national_holidays = holiday_events[holiday_events['locale'] == 'National']
for date in national_holidays['date']:
    train_df.loc[train_df.index == date, 'holiday'] = 1
train_df
# Out:
#                  id  store_nbr                      family     sales  \
# date
# 2013-01-01        0          1                  AUTOMOTIVE     0.000
# 2013-01-01        1          1                   BABY CARE     0.000
# 2013-01-01        2          1                      BEAUTY     0.000
# 2013-01-01        3          1                   BEVERAGES     0.000
# 2013-01-01        4          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 2017-08-15  3000883          9                     POULTRY   438.133
# 2017-08-15  3000884          9              PREPARED FOODS   154.553
# 2017-08-15  3000885          9                     PRODUCE  2419.729
# 2017-08-15  3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2017-08-15  3000887          9                     SEAFOOD    16.000
#
#             onpromotion  holiday
# date
# 2013-01-01            0        1
# 2013-01-01            0        1
# 2013-01-01            0        1
# 2013-01-01            0        1
# 2013-01-01            0        1
# ...                 ...      ...
# 2017-08-15            0        0
# 2017-08-15            1        0
# 2017-08-15          148        0
# 2017-08-15            8        0
# 2017-08-15            0        0
#
# [3000888 rows x 6 columns]

# %%
original_index = train_df.index
train_df = pd.merge(train_df, stores[['store_nbr', 'city', 'state']], on='store_nbr', how='left')
train_df.index = original_index
train_df
# Out:
#                  id  store_nbr                      family     sales  \
# date
# 2013-01-01        0          1                  AUTOMOTIVE     0.000
# 2013-01-01        1          1                   BABY CARE     0.000
# 2013-01-01        2          1                      BEAUTY     0.000
# 2013-01-01        3          1                   BEVERAGES     0.000
# 2013-01-01        4          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 2017-08-15  3000883          9                     POULTRY   438.133
# 2017-08-15  3000884          9              PREPARED FOODS   154.553
# 2017-08-15  3000885          9                     PRODUCE  2419.729
# 2017-08-15  3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2017-08-15  3000887          9                     SEAFOOD    16.000
#
#             onpromotion  holiday   city      state
# date
# 2013-01-01            0        1  Quito  Pichincha
# 2013-01-01            0        1  Quito  Pichincha
# 2013-01-01            0        1  Quito  Pichincha
# 2013-01-01            0        1  Quito  Pichincha
# 2013-01-01            0        1  Quito  Pichincha
# ...                 ...      ...    ...        ...
# 2017-08-15            0        0  Quito  Pichincha
# 2017-08-15            1        0  Quito  Pichincha
# 2017-08-15          148        0  Quito  Pichincha
# 2017-08-15            8        0  Quito  Pichincha
# 2017-08-15            0        0  Quito  Pichincha
#
# [3000888 rows x 8 columns]

# %%
train_df.holiday.value_counts()
# Out:
# holiday
# 0    2758536
# 1     242352
# Name: count, dtype: int64

# %%
# Mark Local/Regional Holidays
local_regional_holidays = holiday_events[holiday_events['locale'] != 'National']
for index, row in local_regional_holidays.iterrows():
    # matching on city
    if 'city' in train_df.columns:
        train_df.loc[(train_df.index == row['date']) & (train_df['city'] == row['locale_name']), 'holiday'] = 1
    # matching on state
    elif 'state' in train_df.columns:
        train_df.loc[(train_df.index == row['date']) & (train_df['state'] == row['locale_name']), 'holiday'] = 1

# %%
train_df.holiday.value_counts()
# Out:
# holiday
# 0    2747118
# 1     253770
# Name: count, dtype: int64

# %%
train_df.columns
# Out:
# Index(['id', 'store_nbr', 'family', 'sales', 'onpromotion', 'holiday', 'city',
#        'state'],
#       dtype='object')

# %% [markdown]
# ## Sale Distributions by Cities, Product Family and Store Number.

# %%
city_sales = train_df.groupby([train_df.index, train_df['city']])['sales'].sum()

# %%
city_sales = city_sales.reset_index()

# %%
city_sales.set_index('date', inplace=True)

# %%
cities = ['Manta','Quito','Santo Domingo']
num_categories = len(cities)

# Define the number of rows and columns for the subplots
ncols = 3
nrows = (num_categories // ncols) + (num_categories % ncols > 0)  # Ensure enough rows

# Create subplots
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16, 4))
axes = axes.flatten()  # Flatten the 2D array of axes to easily iterate over

plt.rcParams.update({'font.size': 8})

# Plot each time series
for i, city in enumerate(cities):
    # Filter sales data for the current city
    sales_data = city_sales[city_sales['city'] == city]
    axes[i].plot(sales_data.index, sales_data['sales'])  # Plot date vs sales for the city
    axes[i].set_title(city)
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Sales')
    axes[i].grid(True)

# Remove any unused subplots
for j in range(num_categories, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
stores
# Out:
#     store_nbr           city                           state type  cluster  \
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# 11         12      Latacunga                        Cotopaxi    C       15
# 12         13      Latacunga                        Cotopaxi    C       15
# 13         14       Riobamba                      Chimborazo    C        7
# 14         15         Ibarra                        Imbabura    C       15
# 15         16  Santo Domingo  Santo Domingo de los Tsachilas    C        3
# 16         17          Quito                       Pichincha    C       12
# 17         18          Quito                       Pichincha    B       16
# 18         19       Guaranda                         Bolivar    C       15
# 19         20          Quito                       Pichincha    B        6
# 20         21  Santo Domingo  Santo Domingo de los Tsachilas    B        6
# 21         22           Puyo                         Pastaza    C        7
# 22         23         Ambato                      Tungurahua    D        9
# 23         24      Guayaquil                          Guayas    D        1
# 24         25        Salinas                     Santa Elena    D        1
# 25         26      Guayaquil                          Guayas    D       10
# 26         27          Daule                          Guayas    D        1
# 27         28      Guayaquil                          Guayas    E       10
# 28         29      Guayaquil                          Guayas    E       10
# 29         30      Guayaquil                          Guayas    C        3
# 30         31       Babahoyo                        Los Rios    B       10
# 31         32      Guayaquil                          Guayas    C        3
# 32         33        Quevedo                        Los Rios    C        3
# 33         34      Guayaquil                          Guayas    B        6
# 34         35         Playas                          Guayas    C        3
# 35         36       Libertad                          Guayas    E       10
# 36         37         Cuenca                           Azuay    D        2
# 37         38           Loja                            Loja    D        4
# 38         39         Cuenca                           Azuay    B        6
# 39         40        Machala                          El Oro    C        3
# 40         41        Machala                          El Oro    D        4
# 41         42         Cuenca                           Azuay    D        2
# 42         43     Esmeraldas                      Esmeraldas    E       10
# 43         44          Quito                       Pichincha    A        5
# 44         45          Quito                       Pichincha    A       11
# 45         46          Quito                       Pichincha    A       14
# 46         47          Quito                       Pichincha    A       14
# 47         48          Quito                       Pichincha    A       14
# 48         49          Quito                       Pichincha    A       11
# 49         50         Ambato                      Tungurahua    A       14
# 50         51      Guayaquil                          Guayas    A       17
# 51         52          Manta                          Manabi    A       11
# 52         53          Manta                          Manabi    D       13
# 53         54      El Carmen                          Manabi    C        3
#
#            sales  onpromotion  transactions
# 0   1.414501e+07       138020       2553963
# 1   2.155739e+07       158149       3219901
# 2   5.048191e+07       177075       5366350
# 3   1.890970e+07       151932       2519007
# 4   1.559240e+07       149370       2347877
# 5   2.518368e+07       169761       3065896
# 6   2.695205e+07       153875       2995993
# 7   3.049429e+07       169671       4637971
# 8   2.640944e+07       177356       3516162
# 9   9.613906e+06       103223       1652493
# 10  2.832556e+07       173787       3972488
# 11  1.065922e+07       117657       1958852
# 12  1.052305e+07       103858       1572504
# 13  1.138792e+07       113036       2287850
# 14  1.145127e+07       120308       2209898
# 15  1.098641e+07       114197       1464498
# 16  1.803097e+07       136778       2295485
# 17  1.325938e+07       134087       2071278
# 18  1.304951e+07       111634       2107489
# 19  1.292095e+07       157358       1422539
# 20  9.255506e+06       144062        842891
# 21  4.090202e+06        99543        504156
# 22  1.165138e+07       128989       1788171
# 23  2.376773e+07       156253       3568206
# 24  1.142100e+07       113542       1520362
# 25  7.755122e+06       111498       1065059
# 26  1.918802e+07       153180       2485687
# 27  1.838315e+07       165200       1957594
# 28  9.725158e+06       153632        981448
# 29  7.382074e+06       103096       1171130
# 30  1.774687e+07       150972       2306044
# 31  5.951796e+06        89932       1065226
# 32  1.417850e+07       136113       1743003
# 33  1.709073e+07       150651       3864018
# 34  7.676679e+06       110104       1123889
# 35  1.532243e+07       158527       1738129
# 36  1.997064e+07       151099       2481719
# 37  1.886000e+07       147223       2867052
# 38  2.025219e+07       173560       2389482
# 39  1.839576e+07       140054       2181195
# 40  1.499104e+07       141329       1764146
# 41  8.945768e+06       124670        802646
# 42  1.639169e+07       124340       2182356
# 43  6.208755e+07       192449       7273093
# 44  5.449801e+07       191503       6201115
# 45  4.189606e+07       190697       5990113
# 46  5.094831e+07       192725       6535810
# 47  3.593313e+07       185566       5107785
# 48  4.342010e+07       184736       4574103
# 49  2.865302e+07       174115       4384444
# 50  3.291149e+07       162576       2873614
# 51  2.696170e+06        30814        275393
# 52  1.121617e+07       204016       1180082
# 53  1.105748e+07       142724       1451290

# %%
stores.state.nunique()
# Out:
# 16

# %%
train_df
# Out:
#                  id  store_nbr                      family     sales  \
# date
# 2013-01-01        0          1                  AUTOMOTIVE     0.000
# 2013-01-01        1          1                   BABY CARE     0.000
# 2013-01-01        2          1                      BEAUTY     0.000
# 2013-01-01        3          1                   BEVERAGES     0.000
# 2013-01-01        4          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 2017-08-15  3000883          9                     POULTRY   438.133
# 2017-08-15  3000884          9              PREPARED FOODS   154.553
# 2017-08-15  3000885          9                     PRODUCE  2419.729
# 2017-08-15  3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2017-08-15  3000887          9                     SEAFOOD    16.000
#
#             onpromotion  holiday   city      state
# date
# 2013-01-01            0        1  Quito  Pichincha
# 2013-01-01            0        1  Quito  Pichincha
# 2013-01-01            0        1  Quito  Pichincha
# 2013-01-01            0        1  Quito  Pichincha
# 2013-01-01            0        1  Quito  Pichincha
# ...                 ...      ...    ...        ...
# 2017-08-15            0        0  Quito  Pichincha
# 2017-08-15            1        0  Quito  Pichincha
# 2017-08-15          148        0  Quito  Pichincha
# 2017-08-15            8        0  Quito  Pichincha
# 2017-08-15            0        0  Quito  Pichincha
#
# [3000888 rows x 8 columns]

# %%
dist_col  = ['store_nbr', 'family', 'city', 'state']
for col in dist_col:
    train_df[col] = train_df[col].astype('category')
    plt.figure(figsize=(10, 8))
    train_df.groupby(col)['sales'].sum().plot.pie(startangle=90)
    plt.title(f'Distribution of {col} by Total Sales')
    plt.ylabel('')
    plt.show()

# %% [markdown]
# A better visualisation method can be plotting a barplot:

# %%
family_exp = train_df.groupby('family')['sales'].sum().sort_values(ascending = False).reset_index()

sns.barplot(x = 'sales', y = family_exp.family, data = family_exp, order = family_exp.family.tolist())
# Out:
# <Axes: xlabel='sales', ylabel='family'>

# %% [markdown]
# ## Exploring Oil DataFrame and how does it correlate with sales

# %%
oil.isna().sum()
# Out:
# dcoilwtico    43
# dtype: int64

# %%
plt.plot(oil)
plt.show()

# %%
oil['dcoilwtico'] = oil['dcoilwtico'].interpolate(method='linear')

# %%
plt.plot(oil)
plt.show()

# %%
oil.isna().sum()
# Out:
# dcoilwtico    1
# dtype: int64

# %%
oil.head()
# Out:
#             dcoilwtico
# date
# 2013-01-01         NaN
# 2013-01-02       93.14
# 2013-01-03       92.97
# 2013-01-04       93.12
# 2013-01-07       93.20

# %%
oil['dcoilwtico'] = oil['dcoilwtico'].interpolate(method='bfill')

# %%
oil.head(5)
# Out:
#             dcoilwtico
# date
# 2013-01-01       93.14
# 2013-01-02       93.14
# 2013-01-03       92.97
# 2013-01-04       93.12
# 2013-01-07       93.20

# %%
print(f'The date range in train_df is {train_df.index.min()} : {train_df.index.max()}')
print(f'The date range in oil dataframe is {oil.index.min()} : {oil.index.max()}')
# Out:
# The date range in train_df is 2013-01-01 00:00:00 : 2017-08-15 00:00:00
# The date range in oil dataframe is 2013-01-01 00:00:00 : 2017-08-31 00:00:00

# %%
oil = oil[:2017-8-31]
#recall that oil values for test set are stored in oil_test

# %% [markdown]
# ### Oil vs Sales

# %%
from sklearn.preprocessing import MinMaxScaler

sales = train_df.groupby(train_df.index)['sales'].sum()
oil_and_sales = pd.merge(oil, sales, left_index=True, right_index=True)

# smoothing oil and sales data (weekly)
window_size = 7
oil_and_sales['dcoilwtico_smooth'] = oil_and_sales['dcoilwtico'].rolling(window=window_size).mean()
oil_and_sales['sales_smooth'] = oil_and_sales['sales'].rolling(window=window_size).mean()

scaler = MinMaxScaler()
oil_and_sales_scaled = oil_and_sales
oil_and_sales_scaled[['dcoilwtico_smooth', 'sales_smooth']] = scaler.fit_transform(oil_and_sales[['dcoilwtico_smooth', 'sales_smooth']])
oil_and_sales_scaled.drop(columns = ['dcoilwtico', 'sales'])
oil_and_sales_scaled= oil_and_sales_scaled.dropna()
oil_and_sales_scaled
# Out:
#             dcoilwtico          sales  dcoilwtico_smooth  sales_smooth
# date
# 2013-01-09       93.08  302530.809018           0.805809      0.043358
# 2013-01-10       93.81  258982.003049           0.807001      0.088064
# 2013-01-11       93.60  289737.685085           0.807820      0.052093
# 2013-01-14       94.27  293348.362078           0.810133      0.040220
# 2013-01-15       93.26  299129.549954           0.810382      0.030576
# ...                ...            ...                ...           ...
# 2017-08-09       49.59  734139.674010           0.260591      0.668604
# 2017-08-10       48.54  651386.911970           0.259434      0.609836
# 2017-08-11       48.81  826373.722022           0.258029      0.585722
# 2017-08-14       47.59  760922.406081           0.255467      0.591449
# 2017-08-15       47.57  762661.935939           0.251908      0.580099
#
# [1197 rows x 4 columns]

# %%
plt.figure(figsize=(10, 5))
plt.plot(oil_and_sales_scaled.index, oil_and_sales_scaled['dcoilwtico_smooth'], linestyle='-', color='blue', label='Scaled Weekly Oil Prices')
plt.plot(oil_and_sales_scaled.index, oil_and_sales_scaled['sales_smooth'], linestyle='-', color='red', label='Scaled Weekly Sales')
plt.title('Smoothed and Scaled Oil Prices and Daily Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Scaled & Smoothed Price / Scaled & Smoothed Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Pearson correlation coefficient between scaled oil and scaled sails
correlation = oil_and_sales_scaled['dcoilwtico_smooth'].corr(oil_and_sales_scaled['sales_smooth'])
print(f"The correlation between scaled weekly oil prices and scaled weekly sales is: {correlation:.2f}")
# Out:
# The correlation between scaled weekly oil prices and scaled weekly sales is: -0.76

# %% [markdown]
# ## Further Exploring Sales

# %%
sales = pd.DataFrame(sales)
sales['lag1'] = sales['sales'].shift(1)
sales['lag7'] = sales['sales'].shift(7)
sales['lag30'] = sales['sales'].shift(30)
sales['lag_year'] = sales['sales'].shift(365)

sales
# Out:
#                     sales           lag1          lag7         lag30  \
# date
# 2013-01-01    2511.618999            NaN           NaN           NaN
# 2013-01-02  496092.417944    2511.618999           NaN           NaN
# 2013-01-03  361461.231124  496092.417944           NaN           NaN
# 2013-01-04  354459.677093  361461.231124           NaN           NaN
# 2013-01-05  477350.121229  354459.677093           NaN           NaN
# ...                   ...            ...           ...           ...
# 2017-08-11  826373.722022  651386.911970  8.277757e+05  7.488000e+05
# 2017-08-12  792630.535079  826373.722022  9.656937e+05  6.296514e+05
# 2017-08-13  865639.677471  792630.535079  1.049559e+06  7.654896e+05
# 2017-08-14  760922.406081  865639.677471  7.974650e+05  9.690771e+05
# 2017-08-15  762661.935939  760922.406081  7.177663e+05  1.100804e+06
#
#                  lag_year
# date
# 2013-01-01            NaN
# 2013-01-02            NaN
# 2013-01-03            NaN
# 2013-01-04            NaN
# 2013-01-05            NaN
# ...                   ...
# 2017-08-11  658457.436112
# 2017-08-12  596729.279945
# 2017-08-13  745662.505149
# 2017-08-14  714905.919067
# 2017-08-15  761826.128978
#
# [1684 rows x 5 columns]

# %%
sales.dropna()
# Out:
#                     sales           lag1          lag7         lag30  \
# date
# 2014-01-02  801011.226041    8602.065404  4.707312e+05  4.954884e+05
# 2014-01-03  680672.845603  801011.226041  4.793150e+05  4.244380e+05
# 2014-01-04  936628.886604  680672.845603  5.569523e+05  4.241470e+05
# 2014-01-05  949618.788940  936628.886604  4.997195e+05  3.864068e+05
# 2014-01-06  602268.564009  949618.788940  6.351347e+05  4.326618e+05
# ...                   ...            ...           ...           ...
# 2017-08-11  826373.722022  651386.911970  8.277757e+05  7.488000e+05
# 2017-08-12  792630.535079  826373.722022  9.656937e+05  6.296514e+05
# 2017-08-13  865639.677471  792630.535079  1.049559e+06  7.654896e+05
# 2017-08-14  760922.406081  865639.677471  7.974650e+05  9.690771e+05
# 2017-08-15  762661.935939  760922.406081  7.177663e+05  1.100804e+06
#
#                  lag_year
# date
# 2014-01-02    2511.618999
# 2014-01-03  496092.417944
# 2014-01-04  361461.231124
# 2014-01-05  354459.677093
# 2014-01-06  477350.121229
# ...                   ...
# 2017-08-11  658457.436112
# 2017-08-12  596729.279945
# 2017-08-13  745662.505149
# 2017-08-14  714905.919067
# 2017-08-15  761826.128978
#
# [1319 rows x 5 columns]

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))

ax[0].scatter(sales['sales'], sales['lag1'], marker='o', linestyle='-')
ax[0].set_title('Correlation Between Previous Day Sales')
ax[0].set_xlabel('Sales')
ax[0].set_ylabel('Lag1')
ax[0].grid(True)

ax[1].scatter(sales['sales'], sales['lag7'], marker='o', linestyle='-')
ax[1].set_title('Correlation Between Previous Week Sales')
ax[1].set_xlabel('Sales')
ax[1].set_ylabel('Lag7')
ax[1].grid(True)

ax[2].scatter(sales['sales'], sales['lag30'], marker='o', linestyle='-')
ax[2].set_title('Correlation Between Previous Month Sales')
ax[2].set_xlabel('Sales')
ax[2].set_ylabel('Lag30')
ax[2].grid(True)

ax[3].scatter(sales['sales'], sales['lag_year'], marker='o', linestyle='-')
ax[3].set_title('Correlation Between Previous Year Sales')
ax[3].set_xlabel('Sales')
ax[3].set_ylabel('lag_year')
ax[3].grid(True)


plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sales number trend and seasonal component

# %%
sales = sales.drop(columns = ['lag1', 'lag7', 'lag30'])
sales
# Out:
#                     sales       lag_year
# date
# 2013-01-01    2511.618999            NaN
# 2013-01-02  496092.417944            NaN
# 2013-01-03  361461.231124            NaN
# 2013-01-04  354459.677093            NaN
# 2013-01-05  477350.121229            NaN
# ...                   ...            ...
# 2017-08-11  826373.722022  658457.436112
# 2017-08-12  792630.535079  596729.279945
# 2017-08-13  865639.677471  745662.505149
# 2017-08-14  760922.406081  714905.919067
# 2017-08-15  762661.935939  761826.128978
#
# [1684 rows x 2 columns]

# %%
trend = sales['sales'].rolling(window = 30, center = True, min_periods = 15).mean()
plt.figure(figsize = (12,5))
ax = sales['sales'].plot(alpha=0.5)
ax = trend.plot(ax=ax, linewidth=3)

# %%
def seasonal_plot(X, y, period, freq, ax=None):
    if ax is None:
        _, ax = plt.subplots()
    palette = sns.color_palette("husl", n_colors=X[period].nunique(),)
    ax = sns.lineplot(
        x=freq,
        y=y,
        hue=period,
        data=X,
        ci=False,
        ax=ax,
        palette=palette,
        legend=False,
    )
    ax.set_title(f"Seasonal Plot ({period}/{freq})")
    for line, name in zip(ax.lines, X[period].unique()):
        y_ = line.get_ydata()[-1]
        ax.annotate(
            name,
            xy=(1, y_),
            xytext=(6, 0),
            color=line.get_color(),
            xycoords=ax.get_yaxis_transform(),
            textcoords="offset points",
            size=14,
            va="center",
        )
    return ax


def plot_periodogram(ts, detrend='linear', ax=None):
    from scipy.signal import periodogram
    fs = pd.Timedelta("365D") / pd.Timedelta("1D")
    freqencies, spectrum = periodogram(
        ts,
        fs=fs,
        detrend=detrend,
        window="boxcar",
        scaling='spectrum',
    )
    if ax is None:
        _, ax = plt.subplots()
    ax.step(freqencies, spectrum, color="purple")
    ax.set_xscale("log")
    ax.set_xticks([1, 2, 4, 6, 12, 26, 52, 104])
    ax.set_xticklabels(
        [
            "Annual (1)",
            "Semiannual (2)",
            "Quarterly (4)",
            "Bimonthly (6)",
            "Monthly (12)",
            "Biweekly (26)",
            "Weekly (52)",
            "Semiweekly (104)",
        ],
        rotation=30,
    )
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    ax.set_ylabel("Variance")
    ax.set_title("Periodogram")
    return ax

# %%
plot_periodogram(sales['sales'])
# Out:
# <Axes: title={'center': 'Periodogram'}, ylabel='Variance'>

# %%
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess
fourier = CalendarFourier(freq="W", order=4)

# %%
dp = DeterministicProcess(
    index=sales.index,
    constant=True,
    order=1,
    seasonal=True,
    additional_terms=[fourier],
    drop=True,
    period = 365)
X = dp.in_sample()

# %%
from sklearn.linear_model import LinearRegression

# %%
y = sales['sales']
X = dp.in_sample()
model = LinearRegression().fit(X, y)
plt.figure(figsize = (18, 5))
y_pred = pd.Series(
    model.predict(X),
    index=X.index,
    name='Fitted',
)


ax = y.plot( alpha=0.5, title="Sales", ylabel="items sold")
ax = y_pred.plot(alpha = 0.5, ax=ax, label="Seasonal")
ax.legend();

# %%
sample_y = y['2016': '2017']
sample_X = X['2016': '2017']
plt.figure(figsize = (18, 5))
sample_pred = pd.Series(
    model.predict(sample_X),
    index=sample_X.index,
    name='Fitted',
)


ax = sample_y.plot( alpha=0.5, title="Sales for 2016:2017", ylabel="items sold")
ax = sample_pred.plot(alpha = 0.5, ax=ax, label="Seasonal")
ax.legend();

# %% [markdown]
# # Incorporating Holiday Data into the model

# %% [markdown]
# For the sake of simplicity, I decided to proceed only with national holidays that affect the sales across all cities.

# %%
X['Holiday'] = X.index.isin(national_holidays.date).astype(bool)

# %%
lr = LinearRegression().fit(X, y)
plt.figure(figsize = (18, 5))
y_pred = pd.Series(
    lr.predict(X),
    index=X.index,
    name='Fitted',
)


ax = y.plot( alpha=0.5, title="Sales", ylabel="items sold")
ax = y_pred.plot(alpha = 0.5, ax=ax, label="Seasonal")
ax.legend();

# %%
#plotting a weekly cycles
# ma = moving average
y_weekly_ma = y.rolling(window = 7, center = True).mean()
plt.figure(figsize = (20, 8))
y_weekly_ma.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Exploring Serial Dependence

# %%
# deseasoning
seasonal_component = y_pred
y_deseason = y -seasonal_component
plt.figure(figsize = (20, 8))
y_deseason.plot()
plt.title('Deseasonalised Plot of Sales ', size = 20)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(y_deseason, zero = False)
plot_pacf(y_deseason, zero  = False)
plt.show()

# %% [markdown]
# We can see that the sales at a particular day are correlated with the sales number on 7 previous days. The PACF shows that the sales are most correalated with the prevous day sales.

# %% [markdown]
# # Modeling

# %% [markdown]
# I will be using a hybrid model consisting of ARIMA model and XGBoost.
# ARIMA model should capture the trend and seasonality that remains in the y_deseason.
# XGBoost in turn would capture complex non linear relationships associated with exogenous variables such as oil price and number of items on promotion.

# %%
from sklearn.preprocessing import StandardScaler

# %%
onpromotions = train_df.groupby(train_df.index)['onpromotion'].sum()
onpromotions
# Out:
# date
# 2013-01-01        0
# 2013-01-02        0
# 2013-01-03        0
# 2013-01-04        0
# 2013-01-05        0
#               ...
# 2017-08-11    14179
# 2017-08-12     8312
# 2017-08-13     9283
# 2017-08-14     8043
# 2017-08-15    10605
# Name: onpromotion, Length: 1684, dtype: int64

# %%
scaler_features = StandardScaler()
scaler_target = StandardScaler()
oil = oil.loc[: '2017-08-15']
train_tot_sales = pd.DataFrame({'sales_deseason' : y_deseason, 'dcoilwtico' : oil['dcoilwtico'], 'onpromotions_total' : onpromotions})
train_tot_sales['dcoilwtico'] = train_tot_sales['dcoilwtico'].interpolate('linear')
train_scaled = train_tot_sales.copy()
train_scaled[['dcoilwtico', 'onpromotions_total']] = scaler_features.fit_transform(train_tot_sales[['dcoilwtico', 'onpromotions_total']])
train_scaled['sales_deseason'] = scaler_target.fit_transform(train_tot_sales[['sales_deseason']])
train_scaled
# Out:
#             sales_deseason  dcoilwtico  onpromotions_total
# date
# 2013-01-01       -4.544173    0.983214           -0.856217
# 2013-01-02        0.698177    0.983214           -0.856217
# 2013-01-03        0.108318    0.976595           -0.856217
# 2013-01-04       -0.282658    0.982435           -0.856217
# 2013-01-05       -1.162299    0.983473           -0.856217
# ...                    ...         ...                 ...
# 2017-08-11       -0.465942   -0.742743            1.761279
# 2017-08-12       -1.493705   -0.758576            0.678209
# 2017-08-13       -1.448520   -0.774410            0.857459
# 2017-08-14       -0.093312   -0.790243            0.628551
# 2017-08-15       -0.215993   -0.791022            1.101505
#
# [1687 rows x 3 columns]

# %%
from statsmodels.tsa.arima.model import ARIMA
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder

class BoostedHybrid:
    def __init__(self, model_1, model_2):
        self.model_1 = model_1  # ARIMA
        self.model_2 = model_2  # XGBoost
        self.y_columns = None

    def fit(self, y, X_2):
        # ARIMA models
        self.model_1 = self.model_1.fit(y)


        y_fit = pd.Series(self.model_1.predict(start=y.index[0], end=y.index[-1]), index=y.index)


        y_resid = y - y_fit

        # Fit the XGBoost model
        self.model_2.fit(X_2, y_resid)


        self.y_columns = y.name if isinstance(y, pd.Series) else y.columns

    def predict(self, index, X_2):
        # Predict with ARIMA
        y_pred_arima = self.model_1.forecast(steps=15)

        # Predict with XGBoost
        y_pred_xgb = pd.Series(self.model_2.predict(X_2), index=X_2.index)


        y_pred = y_pred_arima + y_pred_xgb
        return y_pred

# %%
train_scaled  =train_scaled.dropna()
train_scaled.isna().sum()
# Out:
# sales_deseason        0
# dcoilwtico            0
# onpromotions_total    0
# dtype: int64

# %%
# Split into train and test
train = train_scaled[:-15]
test = train_scaled[-15:]

# %%
y = train['sales_deseason']
X_2 = train[['onpromotions_total', 'dcoilwtico']]


model = BoostedHybrid(
    model_1=ARIMA(y, order=(1,0,0)),
    model_2=XGBRegressor(objective='reg:squarederror')
)
model.fit(y, X_2)
# Out:
# /Users/Heidi/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/Heidi/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/Heidi/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/Heidi/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
y_pred=model.model_2.predict(test[['onpromotions_total', 'dcoilwtico']]) + model.model_1.forecast(steps=15)
# Out:
# /Users/Heidi/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
date_range = pd.date_range(start='2017-08-01', periods=len(test), freq='D')

# %%
y_pred.index = date_range

# %%
y_pred
# Out:
# 2017-08-01    0.266264
# 2017-08-02    0.913433
# 2017-08-03   -0.152357
# 2017-08-04    0.373611
# 2017-08-05   -0.958142
# 2017-08-06   -1.093574
# 2017-08-07   -2.221627
# 2017-08-08   -1.840574
# 2017-08-09   -0.765899
# 2017-08-10   -2.749906
# 2017-08-11   -1.852132
# 2017-08-12   -2.005151
# 2017-08-13   -1.271204
# 2017-08-14   -2.427072
# 2017-08-15   -2.461919
# Freq: D, Name: predicted_mean, dtype: float64

# %%
y_pred_reshaped = y_pred.values.reshape(-1, 1)
y_pred_unscaled  = scaler_target.inverse_transform(y_pred_reshaped)
y_pred_unscaled_series = pd.Series(y_pred_unscaled.flatten(), index=y_pred.index)
y_pred_unscaled_series
# Out:
# 2017-08-01     25758.144888
# 2017-08-02     88364.615969
# 2017-08-03    -14738.829383
# 2017-08-04     36142.780976
# 2017-08-05    -92689.708078
# 2017-08-06   -105791.198235
# 2017-08-07   -214917.968554
# 2017-08-08   -178055.215462
# 2017-08-09    -74092.336316
# 2017-08-10   -266023.090558
# 2017-08-11   -179173.390560
# 2017-08-12   -193976.216120
# 2017-08-13   -122975.009978
# 2017-08-14   -234792.485466
# 2017-08-15   -238163.525497
# Freq: D, dtype: float64

# %%
seasonal_component[-15:]
# Out:
# date
# 2017-08-01    9.056469e+05
# 2017-08-02    9.838594e+05
# 2017-08-03    8.270248e+05
# 2017-08-04    9.052649e+05
# 2017-08-05    1.036231e+06
# 2017-08-06    1.098547e+06
# 2017-08-07    8.397297e+05
# 2017-08-08    8.065038e+05
# 2017-08-09    8.227064e+05
# 2017-08-10    6.873111e+05
# 2017-08-11    8.714485e+05
# 2017-08-12    9.371300e+05
# 2017-08-13    1.005768e+06
# 2017-08-14    7.699493e+05
# 2017-08-15    7.835569e+05
# Name: Fitted, dtype: float64

# %%
y_pred_seasonal = y_pred_unscaled_series + seasonal_component[-15:]

# %%
y_pred_seasonal
# Out:
# 2017-08-01    9.314051e+05
# 2017-08-02    1.072224e+06
# 2017-08-03    8.122860e+05
# 2017-08-04    9.414077e+05
# 2017-08-05    9.435416e+05
# 2017-08-06    9.927556e+05
# 2017-08-07    6.248117e+05
# 2017-08-08    6.284485e+05
# 2017-08-09    7.486141e+05
# 2017-08-10    4.212880e+05
# 2017-08-11    6.922751e+05
# 2017-08-12    7.431538e+05
# 2017-08-13    8.827930e+05
# 2017-08-14    5.351569e+05
# 2017-08-15    5.453933e+05
# Freq: D, dtype: float64

# %%
plt.figure(figsize=(22, 6))
plt.plot( sales['sales'], label='Original Sales', color='blue', alpha = 0.5)
plt.plot( y_pred_seasonal , label='Predictions', color='red', alpha = 0.5)
plt.title('Comparison of Original Sales and Predictions')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
y_test = test['sales_deseason']

# %%
y_test_reshaped = y_test.values.reshape(-1, 1)
y_test_unscaled  = scaler_target.inverse_transform(y_test_reshaped)
y_test_unscaled_series = pd.Series(y_test_unscaled.flatten(), index=y_test.index)
y_test_unscaled_series
# Out:
# date
# 2017-08-01     82880.819255
# 2017-08-02    -19147.395911
# 2017-08-03    -98956.311677
# 2017-08-04    -77489.186622
# 2017-08-05    -70537.690629
# 2017-08-06    -48987.657620
# 2017-08-07    -42264.746281
# 2017-08-08    -88737.408079
# 2017-08-09    -88566.749275
# 2017-08-10    -35924.188068
# 2017-08-11    -45074.796586
# 2017-08-12   -144499.466535
# 2017-08-13   -140128.353327
# 2017-08-14     -9026.943717
# 2017-08-15    -20894.931858
# dtype: float64

# %%
y_test_seasonal = y_test_unscaled_series + seasonal_component[-15:]

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test_seasonal, y_pred_seasonal)
mae
# Out:
# 106116.4574403384

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test_seasonal, y_pred_seasonal)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 16559077000.93007

# %%
mape = np.mean(np.abs((y_test_seasonal -  y_pred_seasonal) / y_test_seasonal)) * 100

# %%
mape
# Out:
# 13.594872187474225

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_seasonal, label='Original Sales', color='blue', alpha = 1)
plt.plot( y_pred_seasonal , label='Predictions', color='red', alpha = 1)
plt.title('Comparison of Original Sales and Predictions')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# ## Exploring Residuals

# %%
residuals = y_test_seasonal -  y_pred_seasonal
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True)
plt.title('Histogram of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# %%
import statsmodels.api as sm

# Calculate the maximum number of lags based on the length of your residuals
max_lags = len(residuals) - 1

# Use the calculated maximum lags or a smaller number if desired
lags_to_use = min(40, max_lags)

sm.graphics.tsa.plot_acf(residuals, lags=lags_to_use, alpha=0.05, zero=False)
sm.qqplot(residuals, line='s')
plt.title('Q-Q Plot of Residuals')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_pred_seasonal, residuals, alpha=0.5)
plt.title('Residuals vs. Predictions')
plt.xlabel('Predictions')
plt.ylabel('Residuals')
plt.axhline(0, color='red', linestyle='--')
plt.show()
